# %% [markdown]
# # EN3150 Homework 01 Data Pre-processing

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://scikit-learn.org/stable/datasets.html

# %% [markdown]
# ## Load the Iris dataset & Explore the dataset

# %%
import pandas as pd
from sklearn.datasets import load_iris

# Load the iris dataset 
dataset = load_iris()
X_full, y_full = dataset.data, dataset.target 
feature_names = dataset.feature_names

# Access the target variable (data labels)
target = dataset.target
target_names = dataset.target_names

# Print the name of the target variable 
print("target_names")
print(target_names)

# Print the feature names
print("Feature Names:")
print(feature_names)

df = pd.DataFrame(X_full, columns=feature_names)

# Calculate statistics for each feature using the describe() function
statistics = df.describe()

# Display the statistics for each feature
print(statistics)
# Out:
# target_names
# ['setosa' 'versicolor' 'virginica']
# Feature Names:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# ## Select the features

# %%
import pandas as pd
from sklearn.datasets import load_iris

# Load the iris dataset 
dataset = load_iris()
X_full, y_full = dataset.data, dataset.target 
feature_names = dataset.feature_names

# Select the desired features
features = ["petal length (cm)", "petal width (cm)"]
features_idx = [list(feature_names).index(feature) for feature in features]
X = X_full[:, features_idx]
df = pd.DataFrame(X_full, columns=feature_names)

# Create a pandas DataFrame with the selected features
df = pd.DataFrame(X, columns=features)

# Calculate statistics for each feature using the describe() function
statistics = df.describe()

# Display the statistics for each feature
print(statistics)
# Out:
#        petal length (cm)  petal width (cm)
# count         150.000000        150.000000
# mean            3.758000          1.199333
# std             1.765298          0.762238
# min             1.000000          0.100000
# 25%             1.600000          0.300000
# 50%             4.350000          1.300000
# 75%             5.100000          1.800000
# max             6.900000          2.500000

# %% [markdown]
# ## different normalization methods

# %% [markdown]
# ## MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Apply Min-Max Scaling to the selected features
X_scaled = scaler.fit_transform(X)

# Plot the data before and after normalization
plt.figure(figsize=(10, 5))

# Plot the data before normalization
plt.subplot(1, 2, 1)
plt.scatter(df["petal length (cm)"], df["petal width (cm)"])
plt.xlabel("petal length (cm)")
plt.ylabel("petal width (cm)")
plt.title("Data Before Normalization")

# Plot the data after normalization
plt.subplot(1, 2, 2)
plt.scatter(X_scaled[:, 0], X_scaled[:, 1])
plt.xlabel("Normalized petal length (cm)")
plt.ylabel("Normalized petal width (cm)")
plt.title("Data After Min-Max Scaling")

plt.tight_layout()
plt.show()

X_MinMaxScaler=X_scaled

# %% [markdown]
# ## StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Initialize the MinMaxScaler
scaler = StandardScaler()

# Apply Standard Scaling to the selected features
X_scaled = scaler.fit_transform(X)

# Plot the data before and after normalization
plt.figure(figsize=(10, 5))

# Plot the data before normalization
plt.subplot(1, 2, 1)
plt.scatter(df["petal length (cm)"], df["petal width (cm)"])
plt.xlabel("petal length (cm)")
plt.ylabel("petal width (cm)")
plt.title("Data Before Normalization")

# Plot the data after normalization
plt.subplot(1, 2, 2)
plt.scatter(X_scaled[:, 0], X_scaled[:, 1])
plt.xlabel("Normalized petal length (cm)")
plt.ylabel("Normalized petal width (cm)")
plt.title("Data After Standard Scaling")

plt.tight_layout()
plt.show()

X_StandardScaler=X_scaled

# %% [markdown]
# ## RobustScaler

# %%
from sklearn.preprocessing import RobustScaler
import matplotlib.pyplot as plt

# Initialize the MinMaxScaler
scaler = RobustScaler()

# Apply Standard Scaling to the selected features
X_scaled = scaler.fit_transform(X)

# Plot the data before and after normalization
plt.figure(figsize=(10, 5))

# Plot the data before normalization
plt.subplot(1, 2, 1)
plt.scatter(df["petal length (cm)"], df["petal width (cm)"])
plt.xlabel("petal length (cm)")
plt.ylabel("petal width (cm)")
plt.title("Data Before Normalization")

# Plot the data after normalization
plt.subplot(1, 2, 2)
plt.scatter(X_scaled[:, 0], X_scaled[:, 1])
plt.xlabel("Normalized petal length (cm)")
plt.ylabel("Normalized petal width (cm)")
plt.title("Data After Robust Scaling")

plt.tight_layout()
plt.show()

X_RobustScaler=X_scaled

# %% [markdown]
# ## Comparision

# %%
# Plot the data after different scaling methods
plt.figure(figsize=(15, 5))

# Plot the data after Min-Max Scaling
plt.subplot(1, 3, 1)
plt.scatter(X_MinMaxScaler[:, 0], X_MinMaxScaler[:, 1])
plt.xlim(-2, 2)  # Set the x-axis limits for zooming
plt.ylim(-2, 2)  # Set the y-axis limits for zooming
plt.xlabel("Normalized petal length (cm)")
plt.ylabel("Normalized petal width (cm)")
plt.title("Data After Min-Max Scaling")

# Plot the data after Standard Scaling
plt.subplot(1, 3, 2)
plt.scatter(X_StandardScaler[:, 0], X_StandardScaler[:, 1])
plt.xlim(-2, 2)  # Set the x-axis limits for zooming
plt.ylim(-2, 2)  # Set the y-axis limits for zooming
plt.xlabel("Standardized petal length (cm)")
plt.ylabel("Standardized petal width (cm)")
plt.title("Data After Standard Scaling")

# Plot the data after Robust Scaling
plt.subplot(1, 3, 3)
plt.scatter(X_RobustScaler[:, 0], X_RobustScaler[:, 1])
plt.xlim(-2, 2)  # Set the x-axis limits for zooming
plt.ylim(-2, 2)  # Set the y-axis limits for zooming
plt.xlabel("Robustly Scaled petal length (cm)")
plt.ylabel("Robustly Scaled petal width (cm)")
plt.title("Data After Robust Scaling")

plt.tight_layout()
plt.show()

# %% [markdown]
# ![1556522351028.png](attachment:1556522351028.png)
